# %% [markdown]
# <a href="https://colab.research.google.com/github/shatha-almalki/CPIT499/blob/main/CPIT499.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AkariUeda/DLAforElsagate.git
# Out:
# Cloning into 'DLAforElsagate'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 413 (delta 0), reused 0 (delta 0), pack-reused 410
# Receiving objects: 100% (413/413), 281.93 MiB | 28.67 MiB/s, done.
# Resolving deltas: 100% (141/141), done.
# Updating files: 100% (180/180), done.

# %%
import os
os.chdir('/content/DLAforElsagate/data_preprocessing')
# !pwd
# !ls
# !./extract_motion_vectors.sh process_porn/list.txt process_porn/porn_frames_previous porn_motion_vectors porn_mvs process_porn/porn
# Out:
# /content/DLAforElsagate/data_preprocessing
# extract_motion_vectors.sh  generate_mvs_imgs.py  split_list_previous_next.bash
# extract_mvs		   process_porn		 test.avi
# frame_extractor		   README.md

# %%
import os
os.chdir('/content/DLAforElsagate/data_preprocessing/frame_extractor')
# !pwd
# !ls
# !cmake build
os.chdir('/content/DLAforElsagate/data_preprocessing/frame_extractor/build')
# !cmake
# !make
# Out:
# /content/DLAforElsagate/data_preprocessing/frame_extractor
# build  CMakeLists.txt  frame_extractor.cpp
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 3.5 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- Configuring done (0.0s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/DLAforElsagate/data_preprocessing/frame_extractor/build
# Usage
#
#   cmake [options] <path-to-source>
#   cmake [options] <path-to-existing-build>
#   cmake [options] -S <path-to-source> -B <path-to-build>
#
# Specify a source directory to (re-)generate a build system for it in the
# current working directory.  Specify an existing build directory to
# re-generate its build system.
#
# Run 'cmake --help' for more information.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# !ls /content/drive/MyDrive/'Copy of CPIT498-Fall2023-2024'
os.chdir("/content/drive/MyDrive/Copy of CPIT498-Fall2023-2024")
# !tar -xvzf safe_videos_fold1-001.tar.gz

# %%
#!ls
#!ls /content/drive/MyDrive/'Copy of CPIT498-Fall2023-2024'/Elsagate-Dataset/train-set
import os
os.chdir("/content/drive/MyDrive/Copy of CPIT498-Fall2023-2024/Elsagate-Dataset/train-set/")
#!ls
# !tar -xvzf elsagate_motions_fold1.tar.gz
#!ls
# Out:
# Streaming output truncated to the last 5000 lines.
# elsagate_motions_fold1/elsagate_0197.mp4-0000781_dx.tif
# elsagate_motions_fold1/elsagate_0496.mp4-0005011_dx.tif
# elsagate_motions_fold1/elsagate_0484.mp4-0002581_dy.tif
# elsagate_motions_fold1/elsagate_1483.mp4-0000091_dy.tif
# elsagate_motions_fold1/elsagate_1740.mp4-0000871_dx.tif
# elsagate_motions_fold1/elsagate_1466.mp4-0005551_dy.tif
# elsagate_motions_fold1/elsagate_0058.mp4-0003931_dx.tif
# elsagate_motions_fold1/elsagate_0834.mp4-0003991_dy.tif
# elsagate_motions_fold1/elsagate_0582.mp4-0005941_dx.tif
# elsagate_motions_fold1/elsagate_0717.mp4-0000901_dx.tif
# elsagate_motions_fold1/elsagate_0242.mp4-0002011_dx.tif
# elsagate_motions_fold1/elsagate_1164.mp4-0005401_dx.tif
# elsagate_motions_fold1/elsagate_0596.mp4-0001111_dx.tif
# elsagate_motions_fold1/elsagate_1816.mp4-0002281_dy.tif
# elsagate_motions_fold1/elsagate_1839.mp4-0002131_dx.tif
# elsagate_motions_fold1/elsagate_1022.mp4-0004231_dx.tif
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile
with ZipFile('drive/MyDrive/CPIT498-Fall2023-2024/Elsagate-Dataset-20230903T203755Z-014.zip','r') as obj:
  obj.extractall('drive/MyDrive/temp')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2344f2152f76> in <cell line: 2>()
#       1 from zipfile import ZipFile
# ----> 2 with ZipFile('drive/MyDrive/CPIT498-Fall2023-2024/Elsagate-Dataset-20230903T203755Z-014.zip','r') as obj:
#       3   obj.extractall('drive/MyDrive/temp')
#       4
#       5
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/CPIT498-Fall2023-2024/Elsagate-Dataset-20230903T203755Z-014.zip'

# %%
import gzip
import shutil
with gzip.open('Elsagate-Dataset/test-set/elsagate_motions_test.tar.gz','rb') as f_in:
  with open('Elsagate-Dataset/test-set/elsagate_motions_test.tar.gz','wb') as f_out:
    shutil.copyfileobj(f_in,f_out)
    print('file created')
# Out:
# file created

# %%
# !pwd
import os
os.chdir('/content/DLAforElsagate/data_preprocessing/')
# !pwd
# !ls
# Out:
# /content
# /content/DLAforElsagate/data_preprocessing
# extract_motion_vectors.sh  frame_extractor	 README.md
# extract_mvs		   generate_mvs_imgs.py  split_list_previous_next.bash

# %%
# !pwd
# !chmod 777 process_porn/list.txt
# !./extract_motion_vectors.sh process_porn/list.txt porn_frames_previous.txt porn_motion_vectors porn_mvs process_porn/porn
# !cd DLAforElsagate/
# !pwd
# !ls
# Out:
# /content/DLAforElsagate/data_preprocessing
# chmod: cannot access 'process_porn/list.txt': No such file or directory
# process_porn/list.txt
# cat: process_porn/list.txt: No such file or directory
